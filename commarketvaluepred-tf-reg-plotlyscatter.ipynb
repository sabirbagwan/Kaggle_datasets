# %%
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np
import openpyxl

import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

# %%
data = pd.read_excel('../input/largest-2000-companies-in-the-world-by-revenue/Largest Companies in the World.xlsx')
data
# Out:
#       Global Rank                     Company  Sales ($billion)  \
# 0             1.0                        ICBC             134.8
# 1             2.0     China Construction Bank             113.1
# 2             3.0              JPMorgan Chase             108.2
# 3             4.0            General Electric             147.4
# 4             5.0                 Exxon Mobil             420.7
# ...           ...                         ...               ...
# 1919       1995.0              Tractor Supply               4.7
# 1920       1996.0                  San-Ai Oil               0.5
# 1921       1996.0                   UOL Group               0.9
# 1922       1998.0     Interconexion Electrica               2.4
# 1923       1999.0  Old Republic International               5.0
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 0                   37.8             2813.5                    237.3
# 1                   30.6             2241.0                    202.0
# 2                   21.3             2359.1                    191.4
# 3                   13.6              685.3                    243.7
# 4                   44.9              333.8                    400.4
# ...                  ...                ...                      ...
# 1919                 0.3                1.7                      7.1
# 1920                 0.1               25.7                      0.5
# 1921                 0.7                7.8                      4.2
# 1922                 0.2               14.6                      5.8
# 1923                -0.1               16.2                      3.3
#
#         Country      Continent   Latitude   Longitude
# 0         China           Asia  35.861660  104.195397
# 1         China           Asia  35.861660  104.195397
# 2           USA  North America  37.090240  -95.712891
# 3           USA  North America  37.090240  -95.712891
# 4           USA  North America  37.090240  -95.712891
# ...         ...            ...        ...         ...
# 1919        USA  North America  37.090240  -95.712891
# 1920      Japan           Asia  36.204824  138.252924
# 1921  Singapore           Asia   1.352083  103.819836
# 1922   Colombia  South America   4.570868  -74.297333
# 1923        USA  North America  37.090240  -95.712891
#
# [1924 rows x 10 columns]

# %%
def preprocess_inputs(df):
    df = df.copy()
    
    # Drop unused columns
    df = df.drop(['Global Rank', 'Company'], axis=1)
    
    # One-hot encode nominal feature columns
    for column in ['Country', 'Continent']:
        dummies = pd.get_dummies(df[column], prefix=column)
        df = pd.concat([df, dummies], axis=1)
        df = df.drop(column, axis=1)
    
    # Split df into X and y
    y = df['Market Value ($billion)']
    X = df.drop('Market Value ($billion)', axis=1)
    
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)
    
    # Scale X
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)

# %%
inputs = tf.keras.Input(shape=(71,))
x = tf.keras.layers.Dense(128, activation='relu')(inputs)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='mse'
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# 2022-12-14 09:29:35.261971: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-12-14 09:29:35.804374: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 34/34 [==============================] - 1s 11ms/step - loss: 1274.0127 - val_loss: 953.7474
# Epoch 2/100
# 34/34 [==============================] - 0s 4ms/step - loss: 919.5852 - val_loss: 770.6577
# Epoch 3/100
# 34/34 [==============================] - 0s 5ms/step - loss: 687.2111 - val_loss: 605.0790
# Epoch 4/100
# 34/34 [==============================] - 0s 4ms/step - loss: 501.3521 - val_loss: 463.6160
# Epoch 5/100
# 34/34 [==============================] - 0s 4ms/step - loss: 368.6263 - val_loss: 384.4033
# Epoch 6/100
# 34/34 [==============================] - 0s 4ms/step - loss: 317.0525 - val_loss: 339.1709
# Epoch 7/100
# 34/34 [==============================] - 0s 4ms/step - loss: 297.6456 - val_loss: 315.9856
# Epoch 8/100
# 34/34 [==============================] - 0s 4ms/step - loss: 275.1404 - val_loss: 294.9369
# Epoch 9/100
# 34/34 [==============================] - 0s 4ms/step - loss: 259.9328 - val_loss: 278.8339
# Epoch 10/100
# 34/34 [==============================] - 0s 4ms/step - loss: 248.2533 - val_loss: 267.0040
# Epoch 11/100
# 34/34 [==============================] - 0s 4ms/step - loss: 238.9017 - val_loss: 253.7831
# Epoch 12/100
# 34/34 [==============================] - 0s 4ms/step - loss: 229.5310 - val_loss: 247.2083
# Epoch 13/100
# 34/34 [==============================] - 0s 4ms/step - loss: 220.6346 - val_loss: 236.8064
# Epoch 14/100
# 34/34 [==============================] - 0s 4ms/step - loss: 213.3704 - val_loss: 226.1438
# Epoch 15/100
# 34/34 [==============================] - 0s 4ms/step - loss: 209.3921 - val_loss: 238.0803
# Epoch 16/100
# 34/34 [==============================] - 0s 4ms/step - loss: 201.5392 - val_loss: 219.0140
# Epoch 17/100
# 34/34 [==============================] - 0s 4ms/step - loss: 199.9758 - val_loss: 220.4901
# Epoch 18/100
# 34/34 [==============================] - 0s 4ms/step - loss: 193.0069 - val_loss: 218.9362
# Epoch 19/100
# 34/34 [==============================] - 0s 5ms/step - loss: 191.9715 - val_loss: 211.4909
# Epoch 20/100
# 34/34 [==============================] - 0s 5ms/step - loss: 191.2109 - val_loss: 211.4531
# Epoch 21/100
# 34/34 [==============================] - 0s 5ms/step - loss: 186.4322 - val_loss: 211.4915
# Epoch 22/100
# 34/34 [==============================] - 0s 6ms/step - loss: 179.9353 - val_loss: 222.3561
# Epoch 23/100
# 34/34 [==============================] - 0s 5ms/step - loss: 187.1806 - val_loss: 206.0068
# Epoch 24/100
# 34/34 [==============================] - 0s 5ms/step - loss: 177.1969 - val_loss: 207.6346
# Epoch 25/100
# 34/34 [==============================] - 0s 5ms/step - loss: 173.4711 - val_loss: 209.7264
# Epoch 26/100
# 34/34 [==============================] - 0s 5ms/step - loss: 180.0007 - val_loss: 207.9497

# %%
y_pred = model.predict(X_test)
y_pred
y_pred.shape
# Out:
# (578, 1)

# %%
y_pred = np.squeeze(model.predict(X_test))
y_pred
y_pred.shape
# Out:
# (578,)

# %%
y_pred = np.squeeze(model.predict(X_test))

rmse = np.sqrt(np.mean((y_test - y_pred)**2))
r2 = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - y_test.mean())**2))

print("RMSE: {:.2f}".format(rmse))
print(" R^2: {:.4f}".format(r2))

fig = px.scatter(
    x=y_pred,
    y=y_test,
    labels={'x': "Predicted", 'y': "Actual"},
    title="Actual vs. Predicted Values",
    width=700,
    height=700
)

fig.show()
# Out:
# RMSE: 17.42
#  R^2: 0.7264
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a45d5402-c33a-4a6b-a436-9621dd3b630e" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a45d5402-c33a-4a6b-a436-9621dd3b630e")) {                    Plotly.newPlot(                        "a45d5402-c33a-4a6b-a436-9621dd3b630e",                        [{"hovertemplate":"Predicted=%{x}<br>Actual=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":